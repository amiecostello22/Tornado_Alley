# %%
import pandas as pd
from pathlib import Path

# %%
# read in dataset
file_path = Path("../Resources/renamed_tornado_data.csv")
tab_df = pd.read_csv(file_path)
print(tab_df.shape)
tab_df.head()
# Out:
# (67558, 14)
#    Year  Month  Day        Date State  Magnitude  Injuries  Fatalities  \
# 0  1950      1    3  1950-01-03    IL          3         3           0
# 1  1950      1    3  1950-01-03    MO          3         3           0
# 2  1950      1    3  1950-01-03    OH          1         1           0
# 3  1950      1   13  1950-01-13    AR          3         1           1
# 4  1950      1   25  1950-01-25    IL          2         0           0
#
#    Start Lat  Start Long  Ending Lat  Ending Long  Length_in_Miles  \
# 0      39.10      -89.30       39.12       -89.23              3.6
# 1      38.77      -90.22       38.83       -90.03              9.5
# 2      40.88      -84.58        0.00         0.00              0.1
# 3      34.40      -94.37        0.00         0.00              0.6
# 4      41.17      -87.33        0.00         0.00              0.1
#
#    Width_in_Yards
# 0             130
# 1             150
# 2              10
# 3              17
# 4             100

# %%
count=tab_df.Magnitude.value_counts()
count
# Out:
#  0    31375
#  1    22885
#  2     9517
#  3     2536
# -9      605
#  4      581
#  5       59
# Name: Magnitude, dtype: int64

# %%
mag = tab_df.loc[tab_df['Magnitude'] == -9]
mag.head()
# Out:
#        Year  Month  Day        Date State  Magnitude  Injuries  Fatalities  \
# 60343  2016      4   15  2016-04-15    CO         -9         0           0
# 60344  2016      4   15  2016-04-15    CO         -9         0           0
# 60345  2016      4   15  2016-04-15    CO         -9         0           0
# 60346  2016      4   15  2016-04-15    CO         -9         0           0
# 60480  2016      5    8  2016-05-08    OK         -9         0           0
#
#        Start Lat  Start Long  Ending Lat  Ending Long  Length_in_Miles  \
# 60343    38.3743   -102.8185     38.4299    -102.8225             3.85
# 60344    38.4046   -102.8083     38.4118    -102.8082             0.50
# 60345    38.4773   -102.7234     38.4944    -102.7191             1.20
# 60346    38.1773   -102.7907     38.1852    -102.7865             0.59
# 60480    34.5810    -98.0760     34.5810     -98.0530             1.30
#
#        Width_in_Yards
# 60343             150
# 60344             100
# 60345             100
# 60346             100
# 60480              40

# %%
df = tab_df[tab_df['Magnitude'] != -9]
print(df.shape)
df.head()
# Out:
# (66953, 14)
#    Year  Month  Day        Date State  Magnitude  Injuries  Fatalities  \
# 0  1950      1    3  1950-01-03    IL          3         3           0
# 1  1950      1    3  1950-01-03    MO          3         3           0
# 2  1950      1    3  1950-01-03    OH          1         1           0
# 3  1950      1   13  1950-01-13    AR          3         1           1
# 4  1950      1   25  1950-01-25    IL          2         0           0
#
#    Start Lat  Start Long  Ending Lat  Ending Long  Length_in_Miles  \
# 0      39.10      -89.30       39.12       -89.23              3.6
# 1      38.77      -90.22       38.83       -90.03              9.5
# 2      40.88      -84.58        0.00         0.00              0.1
# 3      34.40      -94.37        0.00         0.00              0.6
# 4      41.17      -87.33        0.00         0.00              0.1
#
#    Width_in_Yards
# 0             130
# 1             150
# 2              10
# 3              17
# 4             100

# %%
df.dtypes
# Out:
# Year                 int64
# Month                int64
# Day                  int64
# Date                object
# State               object
# Magnitude            int64
# Injuries             int64
# Fatalities           int64
# Start Lat          float64
# Start Long         float64
# Ending Lat         float64
# Ending Long        float64
# Length_in_Miles    float64
# Width_in_Yards       int64
# dtype: object

# %%
df['Number of Tornados']=1
df
# Out:
# C:\Users\matth\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        Year  Month  Day        Date State  Magnitude  Injuries  Fatalities  \
# 0      1950      1    3  1950-01-03    IL          3         3           0
# 1      1950      1    3  1950-01-03    MO          3         3           0
# 2      1950      1    3  1950-01-03    OH          1         1           0
# 3      1950      1   13  1950-01-13    AR          3         1           1
# 4      1950      1   25  1950-01-25    IL          2         0           0
# ...     ...    ...  ...         ...   ...        ...       ...         ...
# 67553  2021     12   30  2021-12-30    GA          1         0           0
# 67554  2021     12   30  2021-12-30    GA          1         0           0
# 67555  2021     12   31  2021-12-31    AL          1         0           0
# 67556  2021     12   31  2021-12-31    GA          1         0           0
# 67557  2021     12   31  2021-12-31    GA          1         6           0
#
#        Start Lat  Start Long  Ending Lat  Ending Long  Length_in_Miles  \
# 0        39.1000    -89.3000     39.1200     -89.2300             3.60
# 1        38.7700    -90.2200     38.8300     -90.0300             9.50
# 2        40.8800    -84.5800      0.0000       0.0000             0.10
# 3        34.4000    -94.3700      0.0000       0.0000             0.60
# 4        41.1700    -87.3300      0.0000       0.0000             0.10
# ...          ...         ...         ...          ...              ...
# 67553    31.1703    -83.3804     31.1805     -83.3453             2.19
# 67554    31.6900    -82.7300     31.7439     -82.5412            11.71
# 67555    34.2875    -85.7878     34.2998     -85.7805             0.95
# 67556    33.7372    -84.9998     33.7625     -84.9633             2.75
# 67557    33.5676    -83.9877     33.5842     -83.9498             2.50
#
#        Width_in_Yards  Number of Tornados
# 0                 130                   1
# 1                 150                   1
# 2                  10                   1
# 3                  17                   1
# 4                 100                   1
# ...               ...                 ...
# 67553             150                   1
# 67554             300                   1
# 67555              50                   1
# 67556             150                   1
# 67557              75                   1
#
# [66953 rows x 15 columns]

# %%
# Export tableau csv
# May need to change your path
df.to_csv("../Resources/tableau.csv", index=False)
