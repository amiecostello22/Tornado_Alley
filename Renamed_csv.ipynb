# %%
import pandas as pd

# %%
df = pd.read_csv("../Resources/us_tornado_dataset_1950_2021.csv")
df.head()
# Out:
#      yr  mo  dy        date  st  mag  inj  fat   slat   slon   elat   elon  \
# 0  1950   1   3  1950-01-03  IL    3    3    0  39.10 -89.30  39.12 -89.23
# 1  1950   1   3  1950-01-03  MO    3    3    0  38.77 -90.22  38.83 -90.03
# 2  1950   1   3  1950-01-03  OH    1    1    0  40.88 -84.58   0.00   0.00
# 3  1950   1  13  1950-01-13  AR    3    1    1  34.40 -94.37   0.00   0.00
# 4  1950   1  25  1950-01-25  IL    2    0    0  41.17 -87.33   0.00   0.00
#
#    len  wid
# 0  3.6  130
# 1  9.5  150
# 2  0.1   10
# 3  0.6   17
# 4  0.1  100

# %%
df.columns = ['year','month','day','date','state','magnitude','injuries',
              'fatalities','start lat','start lon','end lat','end lon','length_miles','width_yards']

# %%
df.head()
# Out:
#    year  month  day        date state  magnitude  injuries  fatalities  \
# 0  1950      1    3  1950-01-03    IL          3         3           0
# 1  1950      1    3  1950-01-03    MO          3         3           0
# 2  1950      1    3  1950-01-03    OH          1         1           0
# 3  1950      1   13  1950-01-13    AR          3         1           1
# 4  1950      1   25  1950-01-25    IL          2         0           0
#
#    start lat  start lon  end lat  end lon  length_miles  width_yards
# 0      39.10     -89.30    39.12   -89.23           3.6          130
# 1      38.77     -90.22    38.83   -90.03           9.5          150
# 2      40.88     -84.58     0.00     0.00           0.1           10
# 3      34.40     -94.37     0.00     0.00           0.6           17
# 4      41.17     -87.33     0.00     0.00           0.1          100

# %%
df.to_csv("../Resources/renamed_tornado_dataset_1950_2021.csv")
