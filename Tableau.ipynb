# %%
import pandas as pd
from pathlib import Path

# %%
# read in dataset
file_path = Path('renamed_tornado_data.csv')
tab_df = pd.read_csv(file_path)
print(tab_df.shape)
tab_df.head()
# Out:
# (67558, 15)
#    Year  Month  Day       Date State  Magnitude  Injuries  Fatalities  \
# 0  1950      1    3   1/3/1950    IL          3         3           0
# 1  1950      1    3   1/3/1950    MO          3         3           0
# 2  1950      1    3   1/3/1950    OH          1         1           0
# 3  1950      1   13  1/13/1950    AR          3         1           1
# 4  1950      1   25  1/25/1950    IL          2         0           0
#
#    Start Lat  Start Long  Ending Lat  Ending Long  Length in Miles  \
# 0      39.10      -89.30       39.12       -89.23              3.6
# 1      38.77      -90.22       38.83       -90.03              9.5
# 2      40.88      -84.58        0.00         0.00              0.1
# 3      34.40      -94.37        0.00         0.00              0.6
# 4      41.17      -87.33        0.00         0.00              0.1
#
#    Width in Yards    MONTH
# 0             130  January
# 1             150  January
# 2              10  January
# ...

# %%
count=tab_df.Magnitude.value_counts()
count
# Out:
#  0    31375
#  1    22885
#  2     9517
#  3     2536
# -9      605
#  4      581
#  5       59
# Name: Magnitude, dtype: int64

# %%
mag = tab_df.loc[tab_df['Magnitude'] == -9]
mag.head()
# Out:
#        Year  Month  Day       Date State  Magnitude  Injuries  Fatalities  \
# 60343  2016      4   15  4/15/2016    CO         -9         0           0
# 60344  2016      4   15  4/15/2016    CO         -9         0           0
# 60345  2016      4   15  4/15/2016    CO         -9         0           0
# 60346  2016      4   15  4/15/2016    CO         -9         0           0
# 60480  2016      5    8   5/8/2016    OK         -9         0           0
#
#        Start Lat  Start Long  Ending Lat  Ending Long  Length in Miles  \
# 60343    38.3743   -102.8185     38.4299    -102.8225             3.85
# 60344    38.4046   -102.8083     38.4118    -102.8082             0.50
# 60345    38.4773   -102.7234     38.4944    -102.7191             1.20
# 60346    38.1773   -102.7907     38.1852    -102.7865             0.59
# 60480    34.5810    -98.0760     34.5810     -98.0530             1.30
#
#        Width in Yards  MONTH
# 60343             150  April
# 60344             100  April
# ...

# %%
df = tab_df[tab_df['Magnitude'] != -9]
print(df.shape)
df.head()
# Out:
# (66953, 15)
#    Year  Month  Day       Date State  Magnitude  Injuries  Fatalities  \
# 0  1950      1    3   1/3/1950    IL          3         3           0
# 1  1950      1    3   1/3/1950    MO          3         3           0
# 2  1950      1    3   1/3/1950    OH          1         1           0
# 3  1950      1   13  1/13/1950    AR          3         1           1
# 4  1950      1   25  1/25/1950    IL          2         0           0
#
#    Start Lat  Start Long  Ending Lat  Ending Long  Length in Miles  \
# 0      39.10      -89.30       39.12       -89.23              3.6
# 1      38.77      -90.22       38.83       -90.03              9.5
# 2      40.88      -84.58        0.00         0.00              0.1
# 3      34.40      -94.37        0.00         0.00              0.6
# 4      41.17      -87.33        0.00         0.00              0.1
#
#    Width in Yards    MONTH
# 0             130  January
# 1             150  January
# 2              10  January
# ...

# %%
df.dtypes
# Out:
# Year                 int64
# Month                int64
# Day                  int64
# Date                object
# State               object
# Magnitude            int64
# Injuries             int64
# Fatalities           int64
# Start Lat          float64
# Start Long         float64
# Ending Lat         float64
# Ending Long        float64
# Length in Miles    float64
# Width in Yards       int64
# MONTH               object
# dtype: object

# %%
df['Number of Tornados']=1
df
# Out:
# C:\Users\Nmera\anaconda3\envs\pythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        Year  Month  Day        Date State  Magnitude  Injuries  Fatalities  \
# 0      1950      1    3    1/3/1950    IL          3         3           0
# 1      1950      1    3    1/3/1950    MO          3         3           0
# 2      1950      1    3    1/3/1950    OH          1         1           0
# 3      1950      1   13   1/13/1950    AR          3         1           1
# 4      1950      1   25   1/25/1950    IL          2         0           0
# ...     ...    ...  ...         ...   ...        ...       ...         ...
# ...

# %%
df.to_csv("Tableau.csv", index=False)
